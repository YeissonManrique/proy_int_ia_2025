# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Cargar archivo Kaggel.jaon

# %%
from google.colab import files
files.upload()  # selecciona el archivo kaggle.json que descargaste
# Out:
#      <input type="file" id="files-a10e5dcc-d219-41a5-9005-2459267f12a8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a10e5dcc-d219-41a5-9005-2459267f12a8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# Descargar datos de la Competencia

# %%
# !kaggle competitions download -c udea-ai-4-eng-20252-pruebas-saber-pro-colombia
# Out:
# ...
#   0% 0.00/29.9M [00:00<?, ?B/s]
# 100% 29.9M/29.9M [00:00<00:00, 983MB/s]

# %% [markdown]
# Descomprimir archivos

# %%
# !unzip udea-ai-4-eng-20252-pruebas-saber-pro-colombia.zip
# Out:
# Archive:  udea-ai-4-eng-20252-pruebas-saber-pro-colombia.zip
#   inflating: submission_example.csv
#   inflating: test.csv
#   inflating: train.csv

# %%
# Carga el archivo de entrenamiento
z = pd.read_csv("train.csv")

# %%
# Muestra la forma (número de filas y columnas)
print("shape of loaded dataframe", z.shape)
# Out:
# shape of loaded dataframe (692500, 21)

# %%
# Muestra las primeras filas
z.head()
# Out:
#        ID  PERIODO_ACADEMICO            E_PRGM_ACADEMICO E_PRGM_DEPARTAMENTO  \
# 0  904256              20212                  ENFERMERIA              BOGOTÁ
# 1  645256              20212                     DERECHO           ATLANTICO
# 2  308367              20203       MERCADEO Y PUBLICIDAD              BOGOTÁ
# 3  470353              20195  ADMINISTRACION DE EMPRESAS           SANTANDER
# 4  989032              20212                  PSICOLOGIA           ANTIOQUIA
#
#                 E_VALORMATRICULAUNIVERSIDAD E_HORASSEMANATRABAJA  \
# 0  Entre 5.5 millones y menos de 7 millones    Menos de 10 horas
# 1  Entre 2.5 millones y menos de 4 millones                    0
# 2  Entre 2.5 millones y menos de 4 millones      Más de 30 horas
# 3  Entre 4 millones y menos de 5.5 millones                    0
# 4  Entre 2.5 millones y menos de 4 millones  Entre 21 y 30 horas
#
#   F_ESTRATOVIVIENDA F_TIENEINTERNET                    F_EDUCACIONPADRE  \
# ...

# %% [markdown]
# Rendimiento Estudiantes

# %%
# Contar la distribución de la variable objetivo
print(z.RENDIMIENTO_GLOBAL.value_counts())
# Out:
# RENDIMIENTO_GLOBAL
# alto          175619
# bajo          172987
# medio-bajo    172275
# medio-alto    171619
# Name: count, dtype: int64

# %%
# Visualizar la distribución de las clases
z.RENDIMIENTO_GLOBAL.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='RENDIMIENTO_GLOBAL'>

# %%
# Contar la distribución de la variable objetivo
print(z.E_PRGM_DEPARTAMENTO.value_counts())
# Out:
# E_PRGM_DEPARTAMENTO
# BOGOTÁ             282159
# ANTIOQUIA           83607
# VALLE               44588
# ATLANTICO           41020
# SANTANDER           28828
# NORTE SANTANDER     22588
# BOLIVAR             20629
# BOYACA              14048
# CUNDINAMARCA        14018
# NARIÑO              13454
# RISARALDA           12679
# CORDOBA             12188
# TOLIMA              11921
# CALDAS              11640
# CAUCA               11471
# HUILA                9995
# MAGDALENA            9512
# SUCRE                8674
# CESAR                8279
# QUINDIO              8229
# META                 7910
# LA GUAJIRA           4778
# CHOCO                4289
# CAQUETA              2659
# CASANARE             1852
# PUTUMAYO              795
# ARAUCA                589
# AMAZONAS               40
# GUAVIARE               37
# VAUPES                 14
# SAN ANDRES             10
# Name: count, dtype: int64

# %%
# Visualizar la distribución de las clases
z.E_PRGM_DEPARTAMENTO.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='E_PRGM_DEPARTAMENTO'>
